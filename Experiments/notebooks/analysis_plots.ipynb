# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# ROOT = Path("../ablation/architecture/label_skew/low")
# FILES = {
#     "none": [
#         "label_skew_low_none_1.json",
#         "label_skew_low_none_2.json",
#         "label_skew_low_none_3.json",
#     ],
#     "fedavg": [
#         "label_skew_low_fedavg_1.json",
#         "label_skew_low_fedavg_2.json",
#         "label_skew_low_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "label_skew_low_fedhca2_1.json",
#         "label_skew_low_fedhca2_2.json",
#         "label_skew_low_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/label_skew/med")
# FILES = {
#     "none": [
#         "label_skew_med_none_1.json",
#         "label_skew_med_none_2.json",
#         "label_skew_med_none_3.json",
#     ],
#     "fedavg": [
#         "label_skew_med_fedavg_1.json",
#         "label_skew_med_fedavg_2.json",
#         "label_skew_med_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "label_skew_med_fedhca2_1.json",
#         "label_skew_med_fedhca2_2.json",
#         "label_skew_med_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/label_skew/high")
# FILES = {
#     "none": [
#         "label_skew_high_none_1.json",
#         "label_skew_high_none_2.json",
#         "label_skew_high_none_3.json",
#     ],
#     "fedavg": [
#         "label_skew_high_fedavg_1.json",
#         "label_skew_high_fedavg_2.json",
#         "label_skew_high_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "label_skew_high_fedhca2_1.json",
#         "label_skew_high_fedhca2_2.json",
#         "label_skew_high_fedhca2_3.json",
#     ],
# }

# %%
# ROOT = Path("../ablation/architecture/quantity_skew/low")
# FILES = {
#     "none": [
#         "quantity_skew_low_none_1.json",
#         "quantity_skew_low_none_2.json",
#         "quantity_skew_low_none_3.json",
#     ],
#     "fedavg": [
#         "quantity_skew_low_fedavg_1.json",
#         "quantity_skew_low_fedavg_2.json",
#         "quantity_skew_low_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "quantity_skew_low_fedhca2_1.json",
#         "quantity_skew_low_fedhca2_2.json",
#         "quantity_skew_low_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/quantity_skew/med")
# FILES = {
#     "none": [
#         "quantity_skew_med_none_1.json",
#         "quantity_skew_med_none_2.json",
#         "quantity_skew_med_none_3.json",
#     ],
#     "fedavg": [
#         "quantity_skew_med_fedavg_1.json",
#         "quantity_skew_med_fedavg_2.json",
#         "quantity_skew_med_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "quantity_skew_med_fedhca2_1.json",
#         "quantity_skew_med_fedhca2_2.json",
#         "quantity_skew_med_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/quantity_skew/high")
# FILES = {
#     "none": [
#         "quantity_skew_high_none_1.json",
#         "quantity_skew_high_none_2.json",
#         "quantity_skew_high_none_3.json",
#     ],
#     "fedavg": [
#         "quantity_skew_high_fedavg_1.json",
#         "quantity_skew_high_fedavg_2.json",
#         "quantity_skew_high_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "quantity_skew_high_fedhca2_1.json",
#         "quantity_skew_high_fedhca2_2.json",
#         "quantity_skew_high_fedhca2_3.json",
#     ],
# }

# %%
ROOT = Path("../ablation/architecture/task_type_overlap/low")
FILES = {
    "none": [
        "task_type_overlap_low_none_1.json",
        "task_type_overlap_low_none_2.json",
        "task_type_overlap_low_none_3.json",
    ],
    "fedavg": [
        "task_type_overlap_low_fedavg_1.json",
        "task_type_overlap_low_fedavg_2.json",
        "task_type_overlap_low_fedavg_3.json",
    ],
    "fedhca2": [
        "task_type_overlap_low_fedhca2_1.json",
        "task_type_overlap_low_fedhca2_2.json",
        "task_type_overlap_low_fedhca2_3.json",
    ],
}

# ROOT = Path("../ablation/architecture/task_type_overlap/med")
# FILES = {
#     "none": [
#         "task_type_overlap_med_none_1.json",
#         "task_type_overlap_med_none_2.json",
#         "task_type_overlap_med_none_3.json",
#     ],
#     "fedavg": [
#         "task_type_overlap_med_fedavg_1.json",
#         "task_type_overlap_med_fedavg_2.json",
#         "task_type_overlap_med_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "task_type_overlap_med_fedhca2_1.json",
#         "task_type_overlap_med_fedhca2_2.json",
#         "task_type_overlap_med_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/task_type_overlap/high")
# FILES = {
#     "none": [
#         "task_type_overlap_high_none_1.json",
#         "task_type_overlap_high_none_2.json",
#         "task_type_overlap_high_none_3.json",
#     ],
#     "fedavg": [
#         "task_type_overlap_high_fedavg_1.json",
#         "task_type_overlap_high_fedavg_2.json",
#         "task_type_overlap_high_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "task_type_overlap_high_fedhca2_1.json",
#         "task_type_overlap_high_fedhca2_2.json",
#         "task_type_overlap_high_fedhca2_3.json",
#     ],
# }

# %%
# ROOT = Path("../ablation/architecture/task_count_imbalance/low")
# FILES = {
#     "none": [
#         "task_count_imbalance_low_none_1.json",
#         "task_count_imbalance_low_none_2.json",
#         "task_count_imbalance_low_none_3.json",
#     ],
#     "fedavg": [
#         "task_count_imbalance_low_fedavg_1.json",
#         "task_count_imbalance_low_fedavg_2.json",
#         "task_count_imbalance_low_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "task_count_imbalance_low_fedhca2_1.json",
#         "task_count_imbalance_low_fedhca2_2.json",
#         "task_count_imbalance_low_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/task_count_imbalance/med")
# FILES = {
#     "none": [
#         "task_count_imbalance_med_none_1.json",
#         "task_count_imbalance_med_none_2.json",
#         "task_count_imbalance_med_none_3.json",
#     ],
#     "fedavg": [
#         "task_count_imbalance_med_fedavg_1.json",
#         "task_count_imbalance_med_fedavg_2.json",
#         "task_count_imbalance_med_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "task_count_imbalance_med_fedhca2_1.json",
#         "task_count_imbalance_med_fedhca2_2.json",
#         "task_count_imbalance_med_fedhca2_3.json",
#     ],
# }

# ROOT = Path("../ablation/architecture/task_count_imbalance/high")
# FILES = {
#     "none": [
#         "task_count_imbalance_high_none_1.json",
#         "task_count_imbalance_high_none_2.json",
#         "task_count_imbalance_high_none_3.json",
#     ],
#     "fedavg": [
#         "task_count_imbalance_high_fedavg_1.json",
#         "task_count_imbalance_high_fedavg_2.json",
#         "task_count_imbalance_high_fedavg_3.json",
#     ],
#     "fedhca2": [
#         "task_count_imbalance_high_fedhca2_1.json",
#         "task_count_imbalance_high_fedhca2_2.json",
#         "task_count_imbalance_high_fedhca2_3.json",
#     ],
# }

# %%
ROUND = 150
TASK_WHITELIST = ["semseg", "normal", "edge", "depth", "saliency"]
PERTASK_COLS   = ["testMetric"]
OVERALL_COLS   = []
SERVER_COLS    = ["meanDeltaNorm", "meanClientDeltaNorm", "meanDistToMean", "meanCosine", "fracNegativeCosine"]

# %%
def get_round_deltaM(round_obj):
    # plot directly; expects scalar numeric
    dm = None
    if isinstance(round_obj, dict):
        if round_obj.get("deltaM") is not None:
            dm = round_obj.get("deltaM")
        elif isinstance(round_obj.get("serverMetrics"), dict) and round_obj["serverMetrics"].get("deltaM") is not None:
            dm = round_obj["serverMetrics"].get("deltaM")

    return float(dm) if isinstance(dm, (int, float)) else None

def build_id_to_index_map(data):
    """
    Prefer header.clients order.
    Fallback: infer from first round's clientMetrics order.
    """
    header_clients = (data.get("header", {}) or {}).get("clients", []) or []
    if header_clients:
        return {c.get("id"): i for i, c in enumerate(header_clients) if c.get("id") is not None}

    rounds = data.get("rounds", []) or []
    if rounds and (rounds[0].get("clientMetrics") is not None):
        cms = rounds[0].get("clientMetrics") or []
        return {cm.get("id"): i for i, cm in enumerate(cms) if cm.get("id") is not None}

    return {}

def parse_file(fp, algo_name, run_id):
    with open(fp, "r") as f:
        data = json.load(f)

    id2idx = build_id_to_index_map(data)

    rows_client, rows_task, rows_server, rows_delta = [], [], [], []

    for r in data.get("rounds", []) or []:
        rnd = r.get("round")

        sm = r.get("serverMetrics") or {}
        rows_server.append({
            "algo": algo_name,
            "run_id": run_id,
            "round": rnd,
            **sm
        })

        rows_delta.append({
            "algo": algo_name,
            "run_id": run_id,
            "round": rnd,
            "deltaM": get_round_deltaM(r)
        })

        cms = r.get("clientMetrics", []) or []
        for j, cm in enumerate(cms):
            cid = cm.get("id")
            cidx = id2idx.get(cid, j)

            rows_client.append({
                "algo": algo_name,
                "run_id": run_id,
                "round": rnd,
                "client_idx": cidx,
                "client_id_raw": cid,
                "epoch": cm.get("epoch"),
                "lossTrain": cm.get("lossTrain"),
                "lossTest": cm.get("lossTest"),
                # "lossTestGlobal": cm.get("lossTestGlobal"),
            })

            for head in cm.get("perHead", []) or []:
                rows_task.append({
                    "algo": algo_name,
                    "run_id": run_id,
                    "round": rnd,
                    "client_idx": cidx,
                    "client_id_raw": cid,
                    "task": head.get("task"),
                    "trainLoss": head.get("trainLoss"),
                    "testLoss": head.get("testLoss"),
                    # "testLossGlobal": head.get("testLossGlobal"),
                    "trainMetric": head.get("trainMetric"),
                    "testMetric": head.get("testMetric"),
                    # "testMetricGlobal": head.get("testMetricGlobal"),
                })

    df_client = pd.DataFrame(rows_client).sort_values(["algo", "run_id", "round", "client_idx"])
    df_task   = pd.DataFrame(rows_task).sort_values(["algo", "run_id", "round", "client_idx", "task"])
    df_server = pd.DataFrame(rows_server).sort_values(["algo", "run_id", "round"])
    df_delta  = pd.DataFrame(rows_delta).sort_values(["algo", "run_id", "round"])

    return df_client, df_task, df_server, df_delta, data

# %%
all_client, all_task, all_server, all_delta = [], [], [], []
raw = {}

for algo, fps in FILES.items():
    raw[algo] = []
    for run_idx, fp in enumerate(fps):
        p = Path(ROOT, fp)
        if not p.exists():
            raise FileNotFoundError(f"Missing: {fp}")

        run_id = f"seed_{run_idx+1}"
        dc, dt, ds, dd, data = parse_file(str(p), algo, run_id)

        all_client.append(dc)
        all_task.append(dt)
        all_server.append(ds)
        all_delta.append(dd)
        raw[algo].append(data)

df_client = pd.concat(all_client, ignore_index=True)
df_task   = pd.concat(all_task, ignore_index=True)
df_server = pd.concat(all_server, ignore_index=True)
df_delta  = pd.concat(all_delta, ignore_index=True)

if ROUND is not None:
    df_client = df_client[df_client["round"] <= ROUND]
    df_task   = df_task[df_task["round"] <= ROUND]
    df_server = df_server[df_server["round"] <= ROUND]
    df_delta  = df_delta[df_delta["round"] <= ROUND]
# Out:
# C:\Users\ern yon\AppData\Local\Temp\ipykernel_32800\3925103440.py:23: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_delta  = pd.concat(all_delta, ignore_index=True)

# %%
def plot_task_mean_across_seeds(df_task, task, y, title, band="std"):
    sub = df_task[df_task["task"] == task].copy()
    if sub.empty or y not in sub.columns:
        return

    # Step 1: reduce each run to one value per round (mean across clients)
    per_run = (
        sub.groupby(["algo", "run_id", "round"], as_index=False)[y]
           .mean()
           .rename(columns={y: "run_mean"})
    )

    plt.figure()

    for algo, g_algo in per_run.groupby("algo"):
        agg = (
            g_algo.groupby("round")["run_mean"]
                 .agg(mean="mean", min="min", max="max", std="std")
                 .reset_index()
                 .sort_values("round")
        )

        x = agg["round"]
        y_mean = agg["mean"]

        plt.plot(x, y_mean, label=algo)

    plt.xlabel("round")
    plt.title(f"{title} — {task}")
    plt.legend()
    plt.show()

# %%
tasks = sorted(df_task["task"].dropna().unique().tolist())

for task in tasks:
    for col in PERTASK_COLS:
        plot_task_mean_across_seeds(
            df_task,
            task,
            col,
            f"Per-task mean across seeds: {col}",
        )
